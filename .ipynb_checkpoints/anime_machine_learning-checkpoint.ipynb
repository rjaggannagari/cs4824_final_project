# %% [markdown]
# # CS-4824 Intro to Machine Learning
# # Rohan Jaggannagari
# # Final Project: Anime Machine Learning
# Note: sources.txt shows which sources were used for this project

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import manhattan_distances
from sklearn.decomposition import PCA
from math import dist

# %% [markdown]
# ## Read in the data
# I read in the data that was cleaned from the other script.

# %%
np.random.seed(4824)

warnings.simplefilter("ignore")

anime_df = pd.read_csv("clean_data/clean_anime_data.csv")
pd.set_option('display.max_columns', 150) # Wanted to see all of the columns

# Getting rid of these columns as of now, but may add them back if I can process them in a proper way
drop_columns = ['English name', 'Synopsis', 'Duration', 'Unnamed: 0', 'Producers', 'Studios']
anime_df = anime_df.drop(columns = drop_columns)
anime_df.set_index('Name', inplace = True)

# Get rid of row with null values
anime_df = anime_df.dropna()

anime_df.head(5)
# Out:
#                                  Score                                Genres  \
# Name
# Cowboy Bebop                      8.75         Action, Award Winning, Sci-Fi
# Cowboy Bebop: Tengoku no Tobira   8.38                        Action, Sci-Fi
# Trigun                            8.22             Action, Adventure, Sci-Fi
# Witch Hunter Robin                7.25  Action, Drama, Mystery, Supernatural
# Bouken Ou Beet                    6.94      Adventure, Fantasy, Supernatural
#
#                                   Type  Episodes  \
# Name
# Cowboy Bebop                        TV      26.0
# Cowboy Bebop: Tengoku no Tobira  Movie       1.0
# Trigun                              TV      26.0
# Witch Hunter Robin                  TV      26.0
# Bouken Ou Beet                      TV      52.0
#
#                                                             Licensors  \
# Name
# Cowboy Bebop                         Funimation, Bandai Entertainment
# Cowboy Bebop: Tengoku no Tobira           Sony Pictures Entertainment
# Trigun                           Funimation, Geneon Entertainment USA
# Witch Hunter Robin                   Funimation, Bandai Entertainment
# Bouken Ou Beet                               Illumitoon Entertainment
#
#                                    Source                          Rating
# Name
# Cowboy Bebop                     Original  R - 17+ (violence & profanity)
# Cowboy Bebop: Tengoku no Tobira  Original  R - 17+ (violence & profanity)
# Trigun                              Manga       PG-13 - Teens 13 or older
# Witch Hunter Robin               Original       PG-13 - Teens 13 or older
# Bouken Ou Beet                      Manga                   PG - Children

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Make episodes all int and reducing their weights
# I need to get rid of any of the rows that do not have episodes since that goes into my machine learning algorithm. An alternative could have been to give those rows a standardized number, but I decided against that. Also, I need to reduce the weights of the episodes since it is calculated using the euclidean distance.

# %%
anime_df['Episodes'] = anime_df['Episodes'].astype(float)
anime_df['Episodes'] = anime_df['Episodes'] * 0.01

anime_df.head(5)
# Out:
#                                  Score                                Genres  \
# Name
# Cowboy Bebop                      8.75         Action, Award Winning, Sci-Fi
# Cowboy Bebop: Tengoku no Tobira   8.38                        Action, Sci-Fi
# Trigun                            8.22             Action, Adventure, Sci-Fi
# Witch Hunter Robin                7.25  Action, Drama, Mystery, Supernatural
# Bouken Ou Beet                    6.94      Adventure, Fantasy, Supernatural
#
#                                   Type  Episodes  \
# Name
# Cowboy Bebop                        TV      1.30
# Cowboy Bebop: Tengoku no Tobira  Movie      0.05
# Trigun                              TV      1.30
# Witch Hunter Robin                  TV      1.30
# Bouken Ou Beet                      TV      2.60
#
#                                                             Licensors  \
# Name
# Cowboy Bebop                         Funimation, Bandai Entertainment
# Cowboy Bebop: Tengoku no Tobira           Sony Pictures Entertainment
# Trigun                           Funimation, Geneon Entertainment USA
# Witch Hunter Robin                   Funimation, Bandai Entertainment
# Bouken Ou Beet                               Illumitoon Entertainment
#
#                                    Source                          Rating
# Name
# Cowboy Bebop                     Original  R - 17+ (violence & profanity)
# Cowboy Bebop: Tengoku no Tobira  Original  R - 17+ (violence & profanity)
# Trigun                              Manga       PG-13 - Teens 13 or older
# Witch Hunter Robin               Original       PG-13 - Teens 13 or older
# Bouken Ou Beet                      Manga                   PG - Children

# %% [markdown]
# ### Increase the weight for the score
# I want to increase the weight for the score so that it is weighted more. The point of the project is personalization and I am someone that wants score higher.

# %%
anime_df['Score'] = anime_df['Score'] * 10
anime_df.head(5)
# Out:
#                                  Score                                Genres  \
# Name
# Cowboy Bebop                     17.50         Action, Award Winning, Sci-Fi
# Cowboy Bebop: Tengoku no Tobira  16.76                        Action, Sci-Fi
# Trigun                           16.44             Action, Adventure, Sci-Fi
# Witch Hunter Robin               14.50  Action, Drama, Mystery, Supernatural
# Bouken Ou Beet                   13.88      Adventure, Fantasy, Supernatural
#
#                                   Type  Episodes  \
# Name
# Cowboy Bebop                        TV      1.30
# Cowboy Bebop: Tengoku no Tobira  Movie      0.05
# Trigun                              TV      1.30
# Witch Hunter Robin                  TV      1.30
# Bouken Ou Beet                      TV      2.60
#
#                                                             Licensors  \
# Name
# Cowboy Bebop                         Funimation, Bandai Entertainment
# Cowboy Bebop: Tengoku no Tobira           Sony Pictures Entertainment
# Trigun                           Funimation, Geneon Entertainment USA
# Witch Hunter Robin                   Funimation, Bandai Entertainment
# Bouken Ou Beet                               Illumitoon Entertainment
#
#                                    Source                          Rating
# Name
# Cowboy Bebop                     Original  R - 17+ (violence & profanity)
# Cowboy Bebop: Tengoku no Tobira  Original  R - 17+ (violence & profanity)
# Trigun                              Manga       PG-13 - Teens 13 or older
# Witch Hunter Robin               Original       PG-13 - Teens 13 or older
# Bouken Ou Beet                      Manga                   PG - Children

# %% [markdown]
# ### Encoding ratings
# Ratings is a scale so the gaosl is to start all ages as 0 and R+ as higher so the recomendation system accounts for that. I could have used a label encoder, but it would have randomly assigned those values and I needed there to be a followed pattern for it.

# %%
# All the categories that are possible
rating_categories = ['G - All Ages', 'PG - Children', 'PG-13 - Teens 13 or older', 'R - 17+ (violence & profanity)', 
                     'R+ - Mild Nudity', 'UNKNOWN']

rating_encoded = list() # Empty list that is going to be added too

# Iterate through each row and find append to a list
for i, current_row in anime_df.iterrows():
    if (current_row['Rating'] == rating_categories[0]):
        rating_encoded.append(0)
    elif (current_row['Rating'] == rating_categories[1]):
        rating_encoded.append(5)
    elif (current_row['Rating'] == rating_categories[2]):
        rating_encoded.append(10)
    elif (current_row['Rating'] == rating_categories[3]):
        rating_encoded.append(15)   
    elif (current_row['Rating'] == rating_categories[4]):
        rating_encoded.append(20)
    elif (current_row['Rating'] == rating_categories[5]):
        rating_encoded.append(25)

# Add the list as a column and drop the old ratings columns as it is not needed
anime_df['Rating Encoded'] = rating_encoded
anime_df = anime_df.drop(columns = 'Rating')

anime_df.head(5)
# Out:
#                                  Score                                Genres  \
# Name
# Cowboy Bebop                     17.50         Action, Award Winning, Sci-Fi
# Cowboy Bebop: Tengoku no Tobira  16.76                        Action, Sci-Fi
# Trigun                           16.44             Action, Adventure, Sci-Fi
# Witch Hunter Robin               14.50  Action, Drama, Mystery, Supernatural
# Bouken Ou Beet                   13.88      Adventure, Fantasy, Supernatural
#
#                                   Type  Episodes  \
# Name
# Cowboy Bebop                        TV      1.30
# Cowboy Bebop: Tengoku no Tobira  Movie      0.05
# Trigun                              TV      1.30
# Witch Hunter Robin                  TV      1.30
# Bouken Ou Beet                      TV      2.60
#
#                                                             Licensors  \
# Name
# Cowboy Bebop                         Funimation, Bandai Entertainment
# Cowboy Bebop: Tengoku no Tobira           Sony Pictures Entertainment
# Trigun                           Funimation, Geneon Entertainment USA
# Witch Hunter Robin                   Funimation, Bandai Entertainment
# Bouken Ou Beet                               Illumitoon Entertainment
#
#                                    Source  Rating Encoded
# Name
# Cowboy Bebop                     Original               3
# Cowboy Bebop: Tengoku no Tobira  Original               3
# Trigun                              Manga               2
# Witch Hunter Robin               Original               2
# Bouken Ou Beet                      Manga               1

# %% [markdown]
# ### Total genres
# I need to get all of the genres to see how many unique ones there are. Depending on how many genres there are that is how many dimensions will be added to the dataframe.

# %%
total_genres = list()

for i, current_row in anime_df.iterrows():
    # Need to put the genres in a list
    split_genres = current_row['Genres'].split(',')
    
    # Iterate through the genres in the the row
    for g in range (0, len(split_genres)):
        # Get rid of any leading white space
        split_genres[g] = split_genres[g].strip()
        
        # Add the unique ones
        if (split_genres[g] not in total_genres):
            total_genres.append(split_genres[g])

print("All genres: " + str(total_genres))
print("Number of genres: " + str(len(total_genres)))
# Out:
# All genres: ['Action', 'Award Winning', 'Sci-Fi', 'Adventure', 'Drama', 'Mystery', 'Supernatural', 'Fantasy', 'Comedy', 'Romance', 'Suspense', 'Sports', 'Ecchi', 'Gourmet', 'Avant Garde', 'Horror', 'Slice of Life', 'Girls Love', 'Boys Love', 'UNKNOWN', 'Erotica']
# Number of genres: 21

# %% [markdown]
# ### Total licensors
# I need to get all of the licensors to see how many unique ones there are. Depending on how many licensors there are that is many dimensions will be added to the dataframe.

# %%
total_licensors = list()

for i, current_row in anime_df.iterrows():
    # Need to put the licensors in a list
    split_licensors = current_row['Licensors'].split(',')
    
    # Iterate through the licensors in the the row
    for g in range (0, len(split_licensors)):
        # Get rid of any leading white space
        split_licensors[g] = split_licensors[g].strip()
        
        # Add the unique ones
        if (split_licensors[g] not in total_licensors):
            total_licensors.append(split_licensors[g])

print("All licensors: " + str(total_licensors))
print("Number of licensors: " + str(len(total_licensors)))
# Out:
# All licensors: ['Funimation', 'Bandai Entertainment', 'Sony Pictures Entertainment', 'Geneon Entertainment USA', 'Illumitoon Entertainment', 'VIZ Media', 'Discotek Media', 'Nozomi Entertainment', 'ADV Films', 'GKIDS', 'Manga Entertainment', 'Media Blasters', 'NYAV Post', 'Aniplex of America', 'AnimEigo', 'Sentai Filmworks', 'UNKNOWN', 'Kadokawa Pictures USA', '4Kids Entertainment', 'Maiden Japan', 'Central Park Media', 'Flatiron Film Company', 'Tokyopop', 'Disney Platform Distribution', 'Harmony Gold', 'Synch-Point', 'Nelvana', 'NIS America', 'Inc.', 'Bandai Visual USA', 'AN Entertainment', 'Urban Vision', 'DreamWorks', 'Warner Bros. Pictures', 'DiC Entertainment', 'Enoki Films', 'Saban Entertainment', 'Crimson Star Media', 'Super Techno Arts', 'Kitty Media', 'Anchor Bay Films', 'Crunchyroll', 'Bandai', 'Eleven Arts', 'Miramax Films', 'Streamline Pictures', 'Shout! Factory', 'The Pokemon Company International', 'Voyager Entertainment', 'Konami Cross Media NY', 'Anime Midstream', 'Hasbro', 'Saban Brands', 'Capcom', 'Hirameki International', 'Cinelicious Pics', 'Arts Magic', 'Frontier Works', 'Pied Piper', 'Mill Creek Entertainment', 'Marvel Entertainment', 'Nintendo of America', 'Dentsu Entertainment USA', 'Cookie Jar Entertainment', 'ADK Emotions NY', 'Ascendent Animation', 'Ketchup Entertainment', 'Kadokawa', 'Ponycan USA', 'Kuma Holdings', 'bilibili', 'NBCUniversal Entertainment Japan', 'Bandai Namco Games', 'Critical Mass Video', 'iQIYI', 'Muse Communication', 'Travel Compass']
# Number of licensors: 77

# %% [markdown]
# ### Total type
# I need to get all of the sources to see how many unique ones there are. Depending on how many sources there are that is how many dimensions will be added to the dataframe.

# %%
total_types = list(anime_df['Type'].unique())

print("All types: " + str(total_types))
print("Number of types: " + str(len(total_types)))
# Out:
# All types: ['TV', 'Movie', 'OVA', 'Special', 'ONA', 'Music', 'UNKNOWN']
# Number of types: 7

# %% [markdown]
# ### Total sources
# I need to get all of the types to see how many unique ones there are. Depending on how many types there are that is how many dimensions will be added to the dataframe.

# %%
total_sources = list(anime_df['Source'].unique())

print("All types: " + str(total_sources))
print("Number of types: " + str(len(total_sources)))
# Out:
# All types: ['Original', 'Manga', 'Light novel', 'Visual novel', '4-koma manga', 'Novel', 'Other', 'Game', 'Picture book', 'Unknown', 'Book', 'Music', 'Card game', 'Radio', 'Mixed media', 'Web manga', 'Web novel']
# Number of types: 17

# %% [markdown]
# ### One hot encoding

# %% [markdown]
# #### Genre
# I needed to create a new column for each genre so that I can cluster it properly later. I would have used the sklearn library, but it would have created a unique one for combination. This way of doing it manually makes it easier to analyze.

# %%
# Add a column for each genre and set it to 0
for genre in total_genres:
    anime_df[genre] = 0
    
for i, current_row in anime_df.iterrows():
    split_genres = current_row['Genres'].split(',')
    
    for f in range (0, len(split_genres)):
        split_genres[f] = split_genres[f].strip()
        
        # If found, set that genre column to 1
        if (split_genres[f] in split_genres):
            anime_df.at[i, split_genres[f]] += 1

# Get rid of the original column
anime_df = anime_df.drop(columns = 'Genres')

anime_df.head(5)
# Out:
#                                  Score   Type  Episodes  \
# Name
# Cowboy Bebop                     17.50     TV      1.30
# Cowboy Bebop: Tengoku no Tobira  16.76  Movie      0.05
# Trigun                           16.44     TV      1.30
# Witch Hunter Robin               14.50     TV      1.30
# Bouken Ou Beet                   13.88     TV      2.60
#
#                                                             Licensors  \
# Name
# Cowboy Bebop                         Funimation, Bandai Entertainment
# Cowboy Bebop: Tengoku no Tobira           Sony Pictures Entertainment
# Trigun                           Funimation, Geneon Entertainment USA
# Witch Hunter Robin                   Funimation, Bandai Entertainment
# Bouken Ou Beet                               Illumitoon Entertainment
#
#                                    Source  Rating Encoded  Action  \
# Name
# Cowboy Bebop                     Original               3       1
# Cowboy Bebop: Tengoku no Tobira  Original               3       1
# Trigun                              Manga               2       1
# Witch Hunter Robin               Original               2       1
# Bouken Ou Beet                      Manga               1       0
#
#                                  Award Winning  Sci-Fi  Adventure  Drama  \
# Name
# Cowboy Bebop                                 1       1          0      0
# Cowboy Bebop: Tengoku no Tobira              0       1          0      0
# Trigun                                       0       1          1      0
# Witch Hunter Robin                           0       0          0      1
# Bouken Ou Beet                               0       0          1      0
#
#                                  Mystery  Supernatural  Fantasy  Comedy  \
# Name
# Cowboy Bebop                           0             0        0       0
# Cowboy Bebop: Tengoku no Tobira        0             0        0       0
# Trigun                                 0             0        0       0
# Witch Hunter Robin                     1             1        0       0
# Bouken Ou Beet                         0             1        1       0
#
#                                  Romance  Suspense  Sports  Ecchi  Gourmet  \
# Name
# Cowboy Bebop                           0         0       0      0        0
# Cowboy Bebop: Tengoku no Tobira        0         0       0      0        0
# Trigun                                 0         0       0      0        0
# Witch Hunter Robin                     0         0       0      0        0
# Bouken Ou Beet                         0         0       0      0        0
#
#                                  Avant Garde  Horror  Slice of Life  \
# Name
# Cowboy Bebop                               0       0              0
# Cowboy Bebop: Tengoku no Tobira            0       0              0
# Trigun                                     0       0              0
# Witch Hunter Robin                         0       0              0
# Bouken Ou Beet                             0       0              0
#
#                                  Girls Love  Boys Love  UNKNOWN  Erotica
# Name
# Cowboy Bebop                              0          0        0        0
# Cowboy Bebop: Tengoku no Tobira           0          0        0        0
# Trigun                                    0          0        0        0
# Witch Hunter Robin                        0          0        0        0
# Bouken Ou Beet                            0          0        0        0

# %% [markdown]
# #### Licensors
# I needed to one hot encode all of the licensors so that I can cluster it more accurately.

# %%
# Add a column for each genre and set it to 0
for licensors in total_licensors:
    if (licensors != 'UNKNOWN'):
        anime_df[licensors] = 0
    
for i, current_row in anime_df.iterrows():
    split_licensors = current_row['Licensors'].split(',')
    
    for f in range (0, len(split_licensors)):
        split_licensors[f] = split_licensors[f].strip()
        
        # If found, set that genre column to 1
        if (split_licensors[f] in split_licensors):
            anime_df.at[i, split_licensors[f]] += 1

# Get rid of the original column
anime_df = anime_df.drop(columns = 'Licensors')

anime_df.head(5)
# Out:
#                                  Score   Type  Episodes    Source  \
# Name
# Cowboy Bebop                     17.50     TV      1.30  Original
# Cowboy Bebop: Tengoku no Tobira  16.76  Movie      0.05  Original
# Trigun                           16.44     TV      1.30     Manga
# Witch Hunter Robin               14.50     TV      1.30  Original
# Bouken Ou Beet                   13.88     TV      2.60     Manga
#
#                                  Rating Encoded  Action  Award Winning  \
# Name
# Cowboy Bebop                                  3       1              1
# Cowboy Bebop: Tengoku no Tobira               3       1              0
# Trigun                                        2       1              0
# Witch Hunter Robin                            2       1              0
# Bouken Ou Beet                                1       0              0
#
#                                  Sci-Fi  Adventure  Drama  Mystery  \
# Name
# Cowboy Bebop                          1          0      0        0
# Cowboy Bebop: Tengoku no Tobira       1          0      0        0
# Trigun                                1          1      0        0
# Witch Hunter Robin                    0          0      1        1
# Bouken Ou Beet                        0          1      0        0
#
#                                  Supernatural  Fantasy  Comedy  Romance  \
# Name
# Cowboy Bebop                                0        0       0        0
# Cowboy Bebop: Tengoku no Tobira             0        0       0        0
# Trigun                                      0        0       0        0
# Witch Hunter Robin                          1        0       0        0
# Bouken Ou Beet                              1        1       0        0
#
#                                  Suspense  Sports  Ecchi  Gourmet  \
# Name
# Cowboy Bebop                            0       0      0        0
# Cowboy Bebop: Tengoku no Tobira         0       0      0        0
# Trigun                                  0       0      0        0
# Witch Hunter Robin                      0       0      0        0
# Bouken Ou Beet                          0       0      0        0
#
#                                  Avant Garde  Horror  Slice of Life  \
# Name
# Cowboy Bebop                               0       0              0
# Cowboy Bebop: Tengoku no Tobira            0       0              0
# Trigun                                     0       0              0
# Witch Hunter Robin                         0       0              0
# Bouken Ou Beet                             0       0              0
#
#                                  Girls Love  Boys Love  UNKNOWN  Erotica  \
# Name
# Cowboy Bebop                              0          0        0        0
# Cowboy Bebop: Tengoku no Tobira           0          0        0        0
# Trigun                                    0          0        0        0
# Witch Hunter Robin                        0          0        0        0
# Bouken Ou Beet                            0          0        0        0
#
#                                  Funimation  Bandai Entertainment  \
# Name
# Cowboy Bebop                              1                     1
# Cowboy Bebop: Tengoku no Tobira           0                     0
# Trigun                                    1                     0
# Witch Hunter Robin                        1                     1
# Bouken Ou Beet                            0                     0
#
#                                  Sony Pictures Entertainment  \
# Name
# Cowboy Bebop                                               0
# Cowboy Bebop: Tengoku no Tobira                            1
# Trigun                                                     0
# Witch Hunter Robin                                         0
# Bouken Ou Beet                                             0
#
#                                  Geneon Entertainment USA  \
# Name
# Cowboy Bebop                                            0
# Cowboy Bebop: Tengoku no Tobira                         0
# Trigun                                                  1
# Witch Hunter Robin                                      0
# Bouken Ou Beet                                          0
#
#                                  Illumitoon Entertainment  VIZ Media  \
# Name
# Cowboy Bebop                                            0          0
# Cowboy Bebop: Tengoku no Tobira                         0          0
# Trigun                                                  0          0
# Witch Hunter Robin                                      0          0
# Bouken Ou Beet                                          1          0
#
#                                  Discotek Media  Nozomi Entertainment  \
# Name
# Cowboy Bebop                                  0                     0
# Cowboy Bebop: Tengoku no Tobira               0                     0
# Trigun                                        0                     0
# Witch Hunter Robin                            0                     0
# Bouken Ou Beet                                0                     0
#
#                                  ADV Films  GKIDS  Manga Entertainment  \
# Name
# Cowboy Bebop                             0      0                    0
# Cowboy Bebop: Tengoku no Tobira          0      0                    0
# Trigun                                   0      0                    0
# Witch Hunter Robin                       0      0                    0
# Bouken Ou Beet                           0      0                    0
#
#                                  Media Blasters  NYAV Post  \
# Name
# Cowboy Bebop                                  0          0
# Cowboy Bebop: Tengoku no Tobira               0          0
# Trigun                                        0          0
# Witch Hunter Robin                            0          0
# Bouken Ou Beet                                0          0
#
#                                  Aniplex of America  AnimEigo  \
# Name
# Cowboy Bebop                                      0         0
# Cowboy Bebop: Tengoku no Tobira                   0         0
# Trigun                                            0         0
# Witch Hunter Robin                                0         0
# Bouken Ou Beet                                    0         0
#
#                                  Sentai Filmworks  Kadokawa Pictures USA  \
# Name
# Cowboy Bebop                                    0                      0
# Cowboy Bebop: Tengoku no Tobira                 0                      0
# Trigun                                          0                      0
# Witch Hunter Robin                              0                      0
# Bouken Ou Beet                                  0                      0
#
#                                  4Kids Entertainment  Maiden Japan  \
# Name
# Cowboy Bebop                                       0             0
# Cowboy Bebop: Tengoku no Tobira                    0             0
# Trigun                                             0             0
# Witch Hunter Robin                                 0             0
# Bouken Ou Beet                                     0             0
#
#                                  Central Park Media  Flatiron Film Company  \
# Name
# Cowboy Bebop                                      0                      0
# Cowboy Bebop: Tengoku no Tobira                   0                      0
# Trigun                                            0                      0
# Witch Hunter Robin                                0                      0
# Bouken Ou Beet                                    0                      0
#
#                                  Tokyopop  Disney Platform Distribution  \
# Name
# Cowboy Bebop                            0                             0
# Cowboy Bebop: Tengoku no Tobira         0                             0
# Trigun                                  0                             0
# Witch Hunter Robin                      0                             0
# Bouken Ou Beet                          0                             0
#
#                                  Harmony Gold  Synch-Point  Nelvana  \
# Name
# Cowboy Bebop                                0            0        0
# Cowboy Bebop: Tengoku no Tobira             0            0        0
# Trigun                                      0            0        0
# Witch Hunter Robin                          0            0        0
# Bouken Ou Beet                              0            0        0
#
#                                  NIS America  Inc.  Bandai Visual USA  \
# Name
# Cowboy Bebop                               0     0                  0
# Cowboy Bebop: Tengoku no Tobira            0     0                  0
# Trigun                                     0     0                  0
# Witch Hunter Robin                         0     0                  0
# Bouken Ou Beet                             0     0                  0
#
#                                  AN Entertainment  Urban Vision  DreamWorks  \
# Name
# Cowboy Bebop                                    0             0           0
# Cowboy Bebop: Tengoku no Tobira                 0             0           0
# Trigun                                          0             0           0
# Witch Hunter Robin                              0             0           0
# Bouken Ou Beet                                  0             0           0
#
#                                  Warner Bros. Pictures  DiC Entertainment  \
# Name
# Cowboy Bebop                                         0                  0
# Cowboy Bebop: Tengoku no Tobira                      0                  0
# Trigun                                               0                  0
# Witch Hunter Robin                                   0                  0
# Bouken Ou Beet                                       0                  0
#
#                                  Enoki Films  Saban Entertainment  \
# Name
# Cowboy Bebop                               0                    0
# Cowboy Bebop: Tengoku no Tobira            0                    0
# Trigun                                     0                    0
# Witch Hunter Robin                         0                    0
# Bouken Ou Beet                             0                    0
#
#                                  Crimson Star Media  Super Techno Arts  \
# Name
# Cowboy Bebop                                      0                  0
# Cowboy Bebop: Tengoku no Tobira                   0                  0
# Trigun                                            0                  0
# Witch Hunter Robin                                0                  0
# Bouken Ou Beet                                    0                  0
#
#                                  Kitty Media  Anchor Bay Films  Crunchyroll  \
# Name
# Cowboy Bebop                               0                 0            0
# Cowboy Bebop: Tengoku no Tobira            0                 0            0
# Trigun                                     0                 0            0
# Witch Hunter Robin                         0                 0            0
# Bouken Ou Beet                             0                 0            0
#
#                                  Bandai  Eleven Arts  Miramax Films  \
# Name
# Cowboy Bebop                          0            0              0
# Cowboy Bebop: Tengoku no Tobira       0            0              0
# Trigun                                0            0              0
# Witch Hunter Robin                    0            0              0
# Bouken Ou Beet                        0            0              0
#
#                                  Streamline Pictures  Shout! Factory  \
# Name
# Cowboy Bebop                                       0               0
# Cowboy Bebop: Tengoku no Tobira                    0               0
# Trigun                                             0               0
# Witch Hunter Robin                                 0               0
# Bouken Ou Beet                                     0               0
#
#                                  The Pokemon Company International  \
# Name
# Cowboy Bebop                                                     0
# Cowboy Bebop: Tengoku no Tobira                                  0
# Trigun                                                           0
# Witch Hunter Robin                                               0
# Bouken Ou Beet                                                   0
#
#                                  Voyager Entertainment  Konami Cross Media NY  \
# Name
# Cowboy Bebop                                         0                      0
# Cowboy Bebop: Tengoku no Tobira                      0                      0
# Trigun                                               0                      0
# Witch Hunter Robin                                   0                      0
# Bouken Ou Beet                                       0                      0
#
#                                  Anime Midstream  Hasbro  Saban Brands  \
# Name
# Cowboy Bebop                                   0       0             0
# Cowboy Bebop: Tengoku no Tobira                0       0             0
# Trigun                                         0       0             0
# Witch Hunter Robin                             0       0             0
# Bouken Ou Beet                                 0       0             0
#
#                                  Capcom  Hirameki International  \
# Name
# Cowboy Bebop                          0                       0
# Cowboy Bebop: Tengoku no Tobira       0                       0
# Trigun                                0                       0
# Witch Hunter Robin                    0                       0
# Bouken Ou Beet                        0                       0
#
#                                  Cinelicious Pics  Arts Magic  Frontier Works  \
# Name
# Cowboy Bebop                                    0           0               0
# Cowboy Bebop: Tengoku no Tobira                 0           0               0
# Trigun                                          0           0               0
# Witch Hunter Robin                              0           0               0
# Bouken Ou Beet                                  0           0               0
#
#                                  Pied Piper  Mill Creek Entertainment  \
# Name
# Cowboy Bebop                              0                         0
# Cowboy Bebop: Tengoku no Tobira           0                         0
# Trigun                                    0                         0
# Witch Hunter Robin                        0                         0
# Bouken Ou Beet                            0                         0
#
#                                  Marvel Entertainment  Nintendo of America  \
# Name
# Cowboy Bebop                                        0                    0
# Cowboy Bebop: Tengoku no Tobira                     0                    0
# Trigun                                              0                    0
# Witch Hunter Robin                                  0                    0
# Bouken Ou Beet                                      0                    0
#
#                                  Dentsu Entertainment USA  \
# Name
# Cowboy Bebop                                            0
# Cowboy Bebop: Tengoku no Tobira                         0
# Trigun                                                  0
# Witch Hunter Robin                                      0
# Bouken Ou Beet                                          0
#
#                                  Cookie Jar Entertainment  ADK Emotions NY  \
# Name
# Cowboy Bebop                                            0                0
# Cowboy Bebop: Tengoku no Tobira                         0                0
# Trigun                                                  0                0
# Witch Hunter Robin                                      0                0
# Bouken Ou Beet                                          0                0
#
#                                  Ascendent Animation  Ketchup Entertainment  \
# Name
# Cowboy Bebop                                       0                      0
# Cowboy Bebop: Tengoku no Tobira                    0                      0
# Trigun                                             0                      0
# Witch Hunter Robin                                 0                      0
# Bouken Ou Beet                                     0                      0
#
#                                  Kadokawa  Ponycan USA  Kuma Holdings  \
# Name
# Cowboy Bebop                            0            0              0
# Cowboy Bebop: Tengoku no Tobira         0            0              0
# Trigun                                  0            0              0
# Witch Hunter Robin                      0            0              0
# Bouken Ou Beet                          0            0              0
#
#                                  bilibili  NBCUniversal Entertainment Japan  \
# Name
# Cowboy Bebop                            0                                 0
# Cowboy Bebop: Tengoku no Tobira         0                                 0
# Trigun                                  0                                 0
# Witch Hunter Robin                      0                                 0
# Bouken Ou Beet                          0                                 0
#
#                                  Bandai Namco Games  Critical Mass Video  \
# Name
# Cowboy Bebop                                      0                    0
# Cowboy Bebop: Tengoku no Tobira                   0                    0
# Trigun                                            0                    0
# Witch Hunter Robin                                0                    0
# Bouken Ou Beet                                    0                    0
#
#                                  iQIYI  Muse Communication  Travel Compass
# Name
# Cowboy Bebop                         0                   0               0
# Cowboy Bebop: Tengoku no Tobira      0                   0               0
# Trigun                               0                   0               0
# Witch Hunter Robin                   0                   0               0
# Bouken Ou Beet                       0                   0               0

# %% [markdown]
# #### Type
# I needed to one hot encode all of the types so that I can cluster it more accurately.

# %%
# Add a column for each type and set it to 0
for c_type in total_types:
    if (c_type != 'UNKNOWN'):
        anime_df[c_type] = 0
        
for i, current_row in anime_df.iterrows():
    stripped_type = current_row['Type']
    
    for f in range (0, len(total_types)):
        if (stripped_type == total_types[f]):
            anime_df.at[i, total_types[f]] += 1
            
# Get rid of the original column
anime_df = anime_df.drop(columns = 'Type')
        
anime_df.head(5)
# Out:
#                                  Score  Episodes    Source  Rating Encoded  \
# Name
# Cowboy Bebop                     17.50      1.30  Original               3
# Cowboy Bebop: Tengoku no Tobira  16.76      0.05  Original               3
# Trigun                           16.44      1.30     Manga               2
# Witch Hunter Robin               14.50      1.30  Original               2
# Bouken Ou Beet                   13.88      2.60     Manga               1
#
#                                  Action  Award Winning  Sci-Fi  Adventure  \
# Name
# Cowboy Bebop                          1              1       1          0
# Cowboy Bebop: Tengoku no Tobira       1              0       1          0
# Trigun                                1              0       1          1
# Witch Hunter Robin                    1              0       0          0
# Bouken Ou Beet                        0              0       0          1
#
#                                  Drama  Mystery  Supernatural  Fantasy  \
# Name
# Cowboy Bebop                         0        0             0        0
# Cowboy Bebop: Tengoku no Tobira      0        0             0        0
# Trigun                               0        0             0        0
# Witch Hunter Robin                   1        1             1        0
# Bouken Ou Beet                       0        0             1        1
#
#                                  Comedy  Romance  Suspense  Sports  Ecchi  \
# Name
# Cowboy Bebop                          0        0         0       0      0
# Cowboy Bebop: Tengoku no Tobira       0        0         0       0      0
# Trigun                                0        0         0       0      0
# Witch Hunter Robin                    0        0         0       0      0
# Bouken Ou Beet                        0        0         0       0      0
#
#                                  Gourmet  Avant Garde  Horror  Slice of Life  \
# Name
# Cowboy Bebop                           0            0       0              0
# Cowboy Bebop: Tengoku no Tobira        0            0       0              0
# Trigun                                 0            0       0              0
# Witch Hunter Robin                     0            0       0              0
# Bouken Ou Beet                         0            0       0              0
#
#                                  Girls Love  Boys Love  UNKNOWN  Erotica  \
# Name
# Cowboy Bebop                              0          0        0        0
# Cowboy Bebop: Tengoku no Tobira           0          0        0        0
# Trigun                                    0          0        0        0
# Witch Hunter Robin                        0          0        0        0
# Bouken Ou Beet                            0          0        0        0
#
#                                  Funimation  Bandai Entertainment  \
# Name
# Cowboy Bebop                              1                     1
# Cowboy Bebop: Tengoku no Tobira           0                     0
# Trigun                                    1                     0
# Witch Hunter Robin                        1                     1
# Bouken Ou Beet                            0                     0
#
#                                  Sony Pictures Entertainment  \
# Name
# Cowboy Bebop                                               0
# Cowboy Bebop: Tengoku no Tobira                            1
# Trigun                                                     0
# Witch Hunter Robin                                         0
# Bouken Ou Beet                                             0
#
#                                  Geneon Entertainment USA  \
# Name
# Cowboy Bebop                                            0
# Cowboy Bebop: Tengoku no Tobira                         0
# Trigun                                                  1
# Witch Hunter Robin                                      0
# Bouken Ou Beet                                          0
#
#                                  Illumitoon Entertainment  VIZ Media  \
# Name
# Cowboy Bebop                                            0          0
# Cowboy Bebop: Tengoku no Tobira                         0          0
# Trigun                                                  0          0
# Witch Hunter Robin                                      0          0
# Bouken Ou Beet                                          1          0
#
#                                  Discotek Media  Nozomi Entertainment  \
# Name
# Cowboy Bebop                                  0                     0
# Cowboy Bebop: Tengoku no Tobira               0                     0
# Trigun                                        0                     0
# Witch Hunter Robin                            0                     0
# Bouken Ou Beet                                0                     0
#
#                                  ADV Films  GKIDS  Manga Entertainment  \
# Name
# Cowboy Bebop                             0      0                    0
# Cowboy Bebop: Tengoku no Tobira          0      0                    0
# Trigun                                   0      0                    0
# Witch Hunter Robin                       0      0                    0
# Bouken Ou Beet                           0      0                    0
#
#                                  Media Blasters  NYAV Post  \
# Name
# Cowboy Bebop                                  0          0
# Cowboy Bebop: Tengoku no Tobira               0          0
# Trigun                                        0          0
# Witch Hunter Robin                            0          0
# Bouken Ou Beet                                0          0
#
#                                  Aniplex of America  AnimEigo  \
# Name
# Cowboy Bebop                                      0         0
# Cowboy Bebop: Tengoku no Tobira                   0         0
# Trigun                                            0         0
# Witch Hunter Robin                                0         0
# Bouken Ou Beet                                    0         0
#
#                                  Sentai Filmworks  Kadokawa Pictures USA  \
# Name
# Cowboy Bebop                                    0                      0
# Cowboy Bebop: Tengoku no Tobira                 0                      0
# Trigun                                          0                      0
# Witch Hunter Robin                              0                      0
# Bouken Ou Beet                                  0                      0
#
#                                  4Kids Entertainment  Maiden Japan  \
# Name
# Cowboy Bebop                                       0             0
# Cowboy Bebop: Tengoku no Tobira                    0             0
# Trigun                                             0             0
# Witch Hunter Robin                                 0             0
# Bouken Ou Beet                                     0             0
#
#                                  Central Park Media  Flatiron Film Company  \
# Name
# Cowboy Bebop                                      0                      0
# Cowboy Bebop: Tengoku no Tobira                   0                      0
# Trigun                                            0                      0
# Witch Hunter Robin                                0                      0
# Bouken Ou Beet                                    0                      0
#
#                                  Tokyopop  Disney Platform Distribution  \
# Name
# Cowboy Bebop                            0                             0
# Cowboy Bebop: Tengoku no Tobira         0                             0
# Trigun                                  0                             0
# Witch Hunter Robin                      0                             0
# Bouken Ou Beet                          0                             0
#
#                                  Harmony Gold  Synch-Point  Nelvana  \
# Name
# Cowboy Bebop                                0            0        0
# Cowboy Bebop: Tengoku no Tobira             0            0        0
# Trigun                                      0            0        0
# Witch Hunter Robin                          0            0        0
# Bouken Ou Beet                              0            0        0
#
#                                  NIS America  Inc.  Bandai Visual USA  \
# Name
# Cowboy Bebop                               0     0                  0
# Cowboy Bebop: Tengoku no Tobira            0     0                  0
# Trigun                                     0     0                  0
# Witch Hunter Robin                         0     0                  0
# Bouken Ou Beet                             0     0                  0
#
#                                  AN Entertainment  Urban Vision  DreamWorks  \
# Name
# Cowboy Bebop                                    0             0           0
# Cowboy Bebop: Tengoku no Tobira                 0             0           0
# Trigun                                          0             0           0
# Witch Hunter Robin                              0             0           0
# Bouken Ou Beet                                  0             0           0
#
#                                  Warner Bros. Pictures  DiC Entertainment  \
# Name
# Cowboy Bebop                                         0                  0
# Cowboy Bebop: Tengoku no Tobira                      0                  0
# Trigun                                               0                  0
# Witch Hunter Robin                                   0                  0
# Bouken Ou Beet                                       0                  0
#
#                                  Enoki Films  Saban Entertainment  \
# Name
# Cowboy Bebop                               0                    0
# Cowboy Bebop: Tengoku no Tobira            0                    0
# Trigun                                     0                    0
# Witch Hunter Robin                         0                    0
# Bouken Ou Beet                             0                    0
#
#                                  Crimson Star Media  Super Techno Arts  \
# Name
# Cowboy Bebop                                      0                  0
# Cowboy Bebop: Tengoku no Tobira                   0                  0
# Trigun                                            0                  0
# Witch Hunter Robin                                0                  0
# Bouken Ou Beet                                    0                  0
#
#                                  Kitty Media  Anchor Bay Films  Crunchyroll  \
# Name
# Cowboy Bebop                               0                 0            0
# Cowboy Bebop: Tengoku no Tobira            0                 0            0
# Trigun                                     0                 0            0
# Witch Hunter Robin                         0                 0            0
# Bouken Ou Beet                             0                 0            0
#
#                                  Bandai  Eleven Arts  Miramax Films  \
# Name
# Cowboy Bebop                          0            0              0
# Cowboy Bebop: Tengoku no Tobira       0            0              0
# Trigun                                0            0              0
# Witch Hunter Robin                    0            0              0
# Bouken Ou Beet                        0            0              0
#
#                                  Streamline Pictures  Shout! Factory  \
# Name
# Cowboy Bebop                                       0               0
# Cowboy Bebop: Tengoku no Tobira                    0               0
# Trigun                                             0               0
# Witch Hunter Robin                                 0               0
# Bouken Ou Beet                                     0               0
#
#                                  The Pokemon Company International  \
# Name
# Cowboy Bebop                                                     0
# Cowboy Bebop: Tengoku no Tobira                                  0
# Trigun                                                           0
# Witch Hunter Robin                                               0
# Bouken Ou Beet                                                   0
#
#                                  Voyager Entertainment  Konami Cross Media NY  \
# Name
# Cowboy Bebop                                         0                      0
# Cowboy Bebop: Tengoku no Tobira                      0                      0
# Trigun                                               0                      0
# Witch Hunter Robin                                   0                      0
# Bouken Ou Beet                                       0                      0
#
#                                  Anime Midstream  Hasbro  Saban Brands  \
# Name
# Cowboy Bebop                                   0       0             0
# Cowboy Bebop: Tengoku no Tobira                0       0             0
# Trigun                                         0       0             0
# Witch Hunter Robin                             0       0             0
# Bouken Ou Beet                                 0       0             0
#
#                                  Capcom  Hirameki International  \
# Name
# Cowboy Bebop                          0                       0
# Cowboy Bebop: Tengoku no Tobira       0                       0
# Trigun                                0                       0
# Witch Hunter Robin                    0                       0
# Bouken Ou Beet                        0                       0
#
#                                  Cinelicious Pics  Arts Magic  Frontier Works  \
# Name
# Cowboy Bebop                                    0           0               0
# Cowboy Bebop: Tengoku no Tobira                 0           0               0
# Trigun                                          0           0               0
# Witch Hunter Robin                              0           0               0
# Bouken Ou Beet                                  0           0               0
#
#                                  Pied Piper  Mill Creek Entertainment  \
# Name
# Cowboy Bebop                              0                         0
# Cowboy Bebop: Tengoku no Tobira           0                         0
# Trigun                                    0                         0
# Witch Hunter Robin                        0                         0
# Bouken Ou Beet                            0                         0
#
#                                  Marvel Entertainment  Nintendo of America  \
# Name
# Cowboy Bebop                                        0                    0
# Cowboy Bebop: Tengoku no Tobira                     0                    0
# Trigun                                              0                    0
# Witch Hunter Robin                                  0                    0
# Bouken Ou Beet                                      0                    0
#
#                                  Dentsu Entertainment USA  \
# Name
# Cowboy Bebop                                            0
# Cowboy Bebop: Tengoku no Tobira                         0
# Trigun                                                  0
# Witch Hunter Robin                                      0
# Bouken Ou Beet                                          0
#
#                                  Cookie Jar Entertainment  ADK Emotions NY  \
# Name
# Cowboy Bebop                                            0                0
# Cowboy Bebop: Tengoku no Tobira                         0                0
# Trigun                                                  0                0
# Witch Hunter Robin                                      0                0
# Bouken Ou Beet                                          0                0
#
#                                  Ascendent Animation  Ketchup Entertainment  \
# Name
# Cowboy Bebop                                       0                      0
# Cowboy Bebop: Tengoku no Tobira                    0                      0
# Trigun                                             0                      0
# Witch Hunter Robin                                 0                      0
# Bouken Ou Beet                                     0                      0
#
#                                  Kadokawa  Ponycan USA  Kuma Holdings  \
# Name
# Cowboy Bebop                            0            0              0
# Cowboy Bebop: Tengoku no Tobira         0            0              0
# Trigun                                  0            0              0
# Witch Hunter Robin                      0            0              0
# Bouken Ou Beet                          0            0              0
#
#                                  bilibili  NBCUniversal Entertainment Japan  \
# Name
# Cowboy Bebop                            0                                 0
# Cowboy Bebop: Tengoku no Tobira         0                                 0
# Trigun                                  0                                 0
# Witch Hunter Robin                      0                                 0
# Bouken Ou Beet                          0                                 0
#
#                                  Bandai Namco Games  Critical Mass Video  \
# Name
# Cowboy Bebop                                      0                    0
# Cowboy Bebop: Tengoku no Tobira                   0                    0
# Trigun                                            0                    0
# Witch Hunter Robin                                0                    0
# Bouken Ou Beet                                    0                    0
#
#                                  iQIYI  Muse Communication  Travel Compass  \
# Name
# Cowboy Bebop                         0                   0               0
# Cowboy Bebop: Tengoku no Tobira      0                   0               0
# Trigun                               0                   0               0
# Witch Hunter Robin                   0                   0               0
# Bouken Ou Beet                       0                   0               0
#
#                                  TV  Movie  OVA  Special  ONA  Music
# Name
# Cowboy Bebop                      1      0    0        0    0      0
# Cowboy Bebop: Tengoku no Tobira   0      1    0        0    0      0
# Trigun                            1      0    0        0    0      0
# Witch Hunter Robin                1      0    0        0    0      0
# Bouken Ou Beet                    1      0    0        0    0      0

# %% [markdown]
# #### Source
# I needed to one hot encode all of the sources so that I can cluster it more accurately.

# %%
# Add a column for each type and set it to 0
for c_sources in total_sources:
    if (c_sources != 'UNKNOWN'):
        anime_df[c_sources] = 0
        
for i, current_row in anime_df.iterrows():
    stripped_sources = current_row['Source']
    
    for f in range (0, len(total_sources)):
        if (stripped_sources == total_sources[f]):
            anime_df.at[i, total_sources[f]] += 1
            
# Get rid of the original column
anime_df = anime_df.drop(columns = 'Source')
        
anime_df.head(5)
# Out:
#                                  Score  Episodes  Rating Encoded  Action  \
# Name
# Cowboy Bebop                     17.50      1.30               3       1
# Cowboy Bebop: Tengoku no Tobira  16.76      0.05               3       1
# Trigun                           16.44      1.30               2       1
# Witch Hunter Robin               14.50      1.30               2       1
# Bouken Ou Beet                   13.88      2.60               1       0
#
#                                  Award Winning  Sci-Fi  Adventure  Drama  \
# Name
# Cowboy Bebop                                 1       1          0      0
# Cowboy Bebop: Tengoku no Tobira              0       1          0      0
# Trigun                                       0       1          1      0
# Witch Hunter Robin                           0       0          0      1
# Bouken Ou Beet                               0       0          1      0
#
#                                  Mystery  Supernatural  Fantasy  Comedy  \
# Name
# Cowboy Bebop                           0             0        0       0
# Cowboy Bebop: Tengoku no Tobira        0             0        0       0
# Trigun                                 0             0        0       0
# Witch Hunter Robin                     1             1        0       0
# Bouken Ou Beet                         0             1        1       0
#
#                                  Romance  Suspense  Sports  Ecchi  Gourmet  \
# Name
# Cowboy Bebop                           0         0       0      0        0
# Cowboy Bebop: Tengoku no Tobira        0         0       0      0        0
# Trigun                                 0         0       0      0        0
# Witch Hunter Robin                     0         0       0      0        0
# Bouken Ou Beet                         0         0       0      0        0
#
#                                  Avant Garde  Horror  Slice of Life  \
# Name
# Cowboy Bebop                               0       0              0
# Cowboy Bebop: Tengoku no Tobira            0       0              0
# Trigun                                     0       0              0
# Witch Hunter Robin                         0       0              0
# Bouken Ou Beet                             0       0              0
#
#                                  Girls Love  Boys Love  UNKNOWN  Erotica  \
# Name
# Cowboy Bebop                              0          0        0        0
# Cowboy Bebop: Tengoku no Tobira           0          0        0        0
# Trigun                                    0          0        0        0
# Witch Hunter Robin                        0          0        0        0
# Bouken Ou Beet                            0          0        0        0
#
#                                  Funimation  Bandai Entertainment  \
# Name
# Cowboy Bebop                              1                     1
# Cowboy Bebop: Tengoku no Tobira           0                     0
# Trigun                                    1                     0
# Witch Hunter Robin                        1                     1
# Bouken Ou Beet                            0                     0
#
#                                  Sony Pictures Entertainment  \
# Name
# Cowboy Bebop                                               0
# Cowboy Bebop: Tengoku no Tobira                            1
# Trigun                                                     0
# Witch Hunter Robin                                         0
# Bouken Ou Beet                                             0
#
#                                  Geneon Entertainment USA  \
# Name
# Cowboy Bebop                                            0
# Cowboy Bebop: Tengoku no Tobira                         0
# Trigun                                                  1
# Witch Hunter Robin                                      0
# Bouken Ou Beet                                          0
#
#                                  Illumitoon Entertainment  VIZ Media  \
# Name
# Cowboy Bebop                                            0          0
# Cowboy Bebop: Tengoku no Tobira                         0          0
# Trigun                                                  0          0
# Witch Hunter Robin                                      0          0
# Bouken Ou Beet                                          1          0
#
#                                  Discotek Media  Nozomi Entertainment  \
# Name
# Cowboy Bebop                                  0                     0
# Cowboy Bebop: Tengoku no Tobira               0                     0
# Trigun                                        0                     0
# Witch Hunter Robin                            0                     0
# Bouken Ou Beet                                0                     0
#
#                                  ADV Films  GKIDS  Manga Entertainment  \
# Name
# Cowboy Bebop                             0      0                    0
# Cowboy Bebop: Tengoku no Tobira          0      0                    0
# Trigun                                   0      0                    0
# Witch Hunter Robin                       0      0                    0
# Bouken Ou Beet                           0      0                    0
#
#                                  Media Blasters  NYAV Post  \
# Name
# Cowboy Bebop                                  0          0
# Cowboy Bebop: Tengoku no Tobira               0          0
# Trigun                                        0          0
# Witch Hunter Robin                            0          0
# Bouken Ou Beet                                0          0
#
#                                  Aniplex of America  AnimEigo  \
# Name
# Cowboy Bebop                                      0         0
# Cowboy Bebop: Tengoku no Tobira                   0         0
# Trigun                                            0         0
# Witch Hunter Robin                                0         0
# Bouken Ou Beet                                    0         0
#
#                                  Sentai Filmworks  Kadokawa Pictures USA  \
# Name
# Cowboy Bebop                                    0                      0
# Cowboy Bebop: Tengoku no Tobira                 0                      0
# Trigun                                          0                      0
# Witch Hunter Robin                              0                      0
# Bouken Ou Beet                                  0                      0
#
#                                  4Kids Entertainment  Maiden Japan  \
# Name
# Cowboy Bebop                                       0             0
# Cowboy Bebop: Tengoku no Tobira                    0             0
# Trigun                                             0             0
# Witch Hunter Robin                                 0             0
# Bouken Ou Beet                                     0             0
#
#                                  Central Park Media  Flatiron Film Company  \
# Name
# Cowboy Bebop                                      0                      0
# Cowboy Bebop: Tengoku no Tobira                   0                      0
# Trigun                                            0                      0
# Witch Hunter Robin                                0                      0
# Bouken Ou Beet                                    0                      0
#
#                                  Tokyopop  Disney Platform Distribution  \
# Name
# Cowboy Bebop                            0                             0
# Cowboy Bebop: Tengoku no Tobira         0                             0
# Trigun                                  0                             0
# Witch Hunter Robin                      0                             0
# Bouken Ou Beet                          0                             0
#
#                                  Harmony Gold  Synch-Point  Nelvana  \
# Name
# Cowboy Bebop                                0            0        0
# Cowboy Bebop: Tengoku no Tobira             0            0        0
# Trigun                                      0            0        0
# Witch Hunter Robin                          0            0        0
# Bouken Ou Beet                              0            0        0
#
#                                  NIS America  Inc.  Bandai Visual USA  \
# Name
# Cowboy Bebop                               0     0                  0
# Cowboy Bebop: Tengoku no Tobira            0     0                  0
# Trigun                                     0     0                  0
# Witch Hunter Robin                         0     0                  0
# Bouken Ou Beet                             0     0                  0
#
#                                  AN Entertainment  Urban Vision  DreamWorks  \
# Name
# Cowboy Bebop                                    0             0           0
# Cowboy Bebop: Tengoku no Tobira                 0             0           0
# Trigun                                          0             0           0
# Witch Hunter Robin                              0             0           0
# Bouken Ou Beet                                  0             0           0
#
#                                  Warner Bros. Pictures  DiC Entertainment  \
# Name
# Cowboy Bebop                                         0                  0
# Cowboy Bebop: Tengoku no Tobira                      0                  0
# Trigun                                               0                  0
# Witch Hunter Robin                                   0                  0
# Bouken Ou Beet                                       0                  0
#
#                                  Enoki Films  Saban Entertainment  \
# Name
# Cowboy Bebop                               0                    0
# Cowboy Bebop: Tengoku no Tobira            0                    0
# Trigun                                     0                    0
# Witch Hunter Robin                         0                    0
# Bouken Ou Beet                             0                    0
#
#                                  Crimson Star Media  Super Techno Arts  \
# Name
# Cowboy Bebop                                      0                  0
# Cowboy Bebop: Tengoku no Tobira                   0                  0
# Trigun                                            0                  0
# Witch Hunter Robin                                0                  0
# Bouken Ou Beet                                    0                  0
#
#                                  Kitty Media  Anchor Bay Films  Crunchyroll  \
# Name
# Cowboy Bebop                               0                 0            0
# Cowboy Bebop: Tengoku no Tobira            0                 0            0
# Trigun                                     0                 0            0
# Witch Hunter Robin                         0                 0            0
# Bouken Ou Beet                             0                 0            0
#
#                                  Bandai  Eleven Arts  Miramax Films  \
# Name
# Cowboy Bebop                          0            0              0
# Cowboy Bebop: Tengoku no Tobira       0            0              0
# Trigun                                0            0              0
# Witch Hunter Robin                    0            0              0
# Bouken Ou Beet                        0            0              0
#
#                                  Streamline Pictures  Shout! Factory  \
# Name
# Cowboy Bebop                                       0               0
# Cowboy Bebop: Tengoku no Tobira                    0               0
# Trigun                                             0               0
# Witch Hunter Robin                                 0               0
# Bouken Ou Beet                                     0               0
#
#                                  The Pokemon Company International  \
# Name
# Cowboy Bebop                                                     0
# Cowboy Bebop: Tengoku no Tobira                                  0
# Trigun                                                           0
# Witch Hunter Robin                                               0
# Bouken Ou Beet                                                   0
#
#                                  Voyager Entertainment  Konami Cross Media NY  \
# Name
# Cowboy Bebop                                         0                      0
# Cowboy Bebop: Tengoku no Tobira                      0                      0
# Trigun                                               0                      0
# Witch Hunter Robin                                   0                      0
# Bouken Ou Beet                                       0                      0
#
#                                  Anime Midstream  Hasbro  Saban Brands  \
# Name
# Cowboy Bebop                                   0       0             0
# Cowboy Bebop: Tengoku no Tobira                0       0             0
# Trigun                                         0       0             0
# Witch Hunter Robin                             0       0             0
# Bouken Ou Beet                                 0       0             0
#
#                                  Capcom  Hirameki International  \
# Name
# Cowboy Bebop                          0                       0
# Cowboy Bebop: Tengoku no Tobira       0                       0
# Trigun                                0                       0
# Witch Hunter Robin                    0                       0
# Bouken Ou Beet                        0                       0
#
#                                  Cinelicious Pics  Arts Magic  Frontier Works  \
# Name
# Cowboy Bebop                                    0           0               0
# Cowboy Bebop: Tengoku no Tobira                 0           0               0
# Trigun                                          0           0               0
# Witch Hunter Robin                              0           0               0
# Bouken Ou Beet                                  0           0               0
#
#                                  Pied Piper  Mill Creek Entertainment  \
# Name
# Cowboy Bebop                              0                         0
# Cowboy Bebop: Tengoku no Tobira           0                         0
# Trigun                                    0                         0
# Witch Hunter Robin                        0                         0
# Bouken Ou Beet                            0                         0
#
#                                  Marvel Entertainment  Nintendo of America  \
# Name
# Cowboy Bebop                                        0                    0
# Cowboy Bebop: Tengoku no Tobira                     0                    0
# Trigun                                              0                    0
# Witch Hunter Robin                                  0                    0
# Bouken Ou Beet                                      0                    0
#
#                                  Dentsu Entertainment USA  \
# Name
# Cowboy Bebop                                            0
# Cowboy Bebop: Tengoku no Tobira                         0
# Trigun                                                  0
# Witch Hunter Robin                                      0
# Bouken Ou Beet                                          0
#
#                                  Cookie Jar Entertainment  ADK Emotions NY  \
# Name
# Cowboy Bebop                                            0                0
# Cowboy Bebop: Tengoku no Tobira                         0                0
# Trigun                                                  0                0
# Witch Hunter Robin                                      0                0
# Bouken Ou Beet                                          0                0
#
#                                  Ascendent Animation  Ketchup Entertainment  \
# Name
# Cowboy Bebop                                       0                      0
# Cowboy Bebop: Tengoku no Tobira                    0                      0
# Trigun                                             0                      0
# Witch Hunter Robin                                 0                      0
# Bouken Ou Beet                                     0                      0
#
#                                  Kadokawa  Ponycan USA  Kuma Holdings  \
# Name
# Cowboy Bebop                            0            0              0
# Cowboy Bebop: Tengoku no Tobira         0            0              0
# Trigun                                  0            0              0
# Witch Hunter Robin                      0            0              0
# Bouken Ou Beet                          0            0              0
#
#                                  bilibili  NBCUniversal Entertainment Japan  \
# Name
# Cowboy Bebop                            0                                 0
# Cowboy Bebop: Tengoku no Tobira         0                                 0
# Trigun                                  0                                 0
# Witch Hunter Robin                      0                                 0
# Bouken Ou Beet                          0                                 0
#
#                                  Bandai Namco Games  Critical Mass Video  \
# Name
# Cowboy Bebop                                      0                    0
# Cowboy Bebop: Tengoku no Tobira                   0                    0
# Trigun                                            0                    0
# Witch Hunter Robin                                0                    0
# Bouken Ou Beet                                    0                    0
#
#                                  iQIYI  Muse Communication  Travel Compass  \
# Name
# Cowboy Bebop                         0                   0               0
# Cowboy Bebop: Tengoku no Tobira      0                   0               0
# Trigun                               0                   0               0
# Witch Hunter Robin                   0                   0               0
# Bouken Ou Beet                       0                   0               0
#
#                                  TV  Movie  OVA  Special  ONA  Music  \
# Name
# Cowboy Bebop                      1      0    0        0    0      0
# Cowboy Bebop: Tengoku no Tobira   0      1    0        0    0      0
# Trigun                            1      0    0        0    0      0
# Witch Hunter Robin                1      0    0        0    0      0
# Bouken Ou Beet                    1      0    0        0    0      0
#
#                                  Original  Manga  Light novel  Visual novel  \
# Name
# Cowboy Bebop                            1      0            0             0
# Cowboy Bebop: Tengoku no Tobira         1      0            0             0
# Trigun                                  0      1            0             0
# Witch Hunter Robin                      1      0            0             0
# Bouken Ou Beet                          0      1            0             0
#
#                                  4-koma manga  Novel  Other  Game  \
# Name
# Cowboy Bebop                                0      0      0     0
# Cowboy Bebop: Tengoku no Tobira             0      0      0     0
# Trigun                                      0      0      0     0
# Witch Hunter Robin                          0      0      0     0
# Bouken Ou Beet                              0      0      0     0
#
#                                  Picture book  Unknown  Book  Card game  \
# Name
# Cowboy Bebop                                0        0     0          0
# Cowboy Bebop: Tengoku no Tobira             0        0     0          0
# Trigun                                      0        0     0          0
# Witch Hunter Robin                          0        0     0          0
# Bouken Ou Beet                              0        0     0          0
#
#                                  Radio  Mixed media  Web manga  Web novel
# Name
# Cowboy Bebop                         0            0          0          0
# Cowboy Bebop: Tengoku no Tobira      0            0          0          0
# Trigun                               0            0          0          0
# Witch Hunter Robin                   0            0          0          0
# Bouken Ou Beet                       0            0          0          0

# %% [markdown]
# ## K Means Clustering

# %% [markdown]
# ### Put in chosen animes
# I have provided some sample animes that are different, but have some similarties.

# %%
# Choose the animes that you have liked
chosen_animes = ["Naruto", "Jujutsu Kaisen", "Bleach", "Deathnote"]

chosen_index_values = list()
current_index = 0
# Gets the data for those animes that you listed
for i, current_row in anime_df.iterrows():
    for g in range (0, len(chosen_animes)):
        if (str(chosen_animes[g]) == str(i)):
            chosen_index_values.append(current_index)
    current_index = current_index + 1
chosen_index_values

# Get the mean so you can use it in a prediction
predict_input = np.array(anime_df.iloc[chosen_index_values].mean(axis = 0))

# %% [markdown]
# ### Apply k-means
# Using an unsupervised machine learning algorithm since there are no labels for the data.

# %%
print("Anime Recomendation Results with k-Means")
print("Anime Inputs: " + str(chosen_animes) + '\n')

k_clusters = [10, 25, 50, 75, 100, 150, 200, 400]

# Iterarte through all of the listed k values above
for g in range (0, len(k_clusters)):
    km = KMeans(n_clusters = k_clusters[g])
    # Fit the cleaned and processed dataset
    km.fit(anime_df)

    fitted_clusters = km.labels_ # Get the actual cluster values
    predicted_cluster = km.predict(predict_input.reshape(1, -1)) # The cluster that matters

    found_index_values = list()
    current_index = 0
    # Get the index values of the animes in the cluster predicted
    for i, current_row in anime_df.iterrows():
        if (int(fitted_clusters[current_index]) == int(predicted_cluster[0])):
            found_index_values.append(current_index)
        current_index = current_index + 1

    # Get all of the anime names
    results = list(anime_df.iloc[found_index_values].index)
    
    # The dataframe that will store the final results for each iteration
    output_df = pd.DataFrame(results, columns = ['Recomended Animes'])
    
    # Metrics to see how the results were
    output_df['Eucldiean Distance'] = 0
    output_df['Manhattan Distance'] = 0
    output_df['Cosine Similarity'] = 0
    
    # Loop through and add the metric data
    for h, current_r_row in output_df.iterrows():
        current_anime = current_r_row['Recomended Animes']
        
        anime_df_count = 0
        # Iterate to find all of the needed anime data to do more analysis
        for l, current_a_row in anime_df.iterrows():
            if (str(l) == str(current_anime)): # Check the animes names are the same to extract data
                anime_data = np.array(anime_df.iloc[anime_df_count])
                
                euc_dist = dist(anime_data, predict_input)
                cos_sim = cosine_similarity(anime_data.reshape(1,-1), predict_input.reshape(1,-1)) # Needed to reshape or error
                man_dist = manhattan_distances(anime_data.reshape(1,-1), predict_input.reshape(1,-1)) # Needed to reshape or error
                
                output_df['Eucldiean Distance'][h] = euc_dist
                output_df['Cosine Similarity'][h] = cos_sim
                output_df['Manhattan Distance'][h] = man_dist
                
                break
                
            anime_df_count = anime_df_count + 1

    print("k Value:" + str(k_clusters[g]))
    
    output_df = output_df.sort_values(by = 'Eucldiean Distance') # Sorting by this metric
    output_df.set_index('Recomended Animes', inplace = True)
    
    # Get rid of the animes that were in the input
    for f in range (0, len(chosen_animes)):
        if(chosen_animes[f] in output_df.index):
            output_df.drop(chosen_animes[f], inplace = True)
    
    display(output_df.head(50))
    print(len(output_df))
# Out:
# Anime Recomendation Results with k-Means
# Anime Inputs: ['Naruto', 'Jujutsu Kaisen', 'Bleach', 'Deathnote']
#
# k Value:10
#                                            Eucldiean Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                               1.917895
# InuYasha                                             2.247618
# Fairy Tail                                           2.417641
# Yu☆Gi☆Oh! Duel Monsters                              2.525831
# Tennis no Ouji-sama                                  2.586366
# Black Clover                                         2.729827
# Gintama                                              2.995072
# Urusei Yatsura                                       3.054339
# Ranma ½                                              3.087144
# Pokemon Diamond & Pearl                              3.128970
# Yu☆Gi☆Oh! Duel Monsters GX                           3.158263
# Pokemon Advanced Generation                          3.453880
# Yadamon                                              3.624613
# Wagamama☆Fairy Mirumo de Pon!                        3.904129
# Tetsuwan Atom                                        3.975297
# Pokonyan!                                            4.123084
# Ni Tian Zhizun                                       4.602169
# Pokemon                                              4.674094
# Dragon Ball Z                                        4.748592
# Youkai Watch                                         4.969489
# Chirorin Mura Monogatari                             5.042733
# Furusato Saisei: Nippon no Mukashibanashi            5.211713
# Tottoko Hamtarou                                     5.985869
# Boruto: Naruto Next Generations                      6.202241
# Ikkyuu-san                                           6.507316
# Atashin'chi                                          7.417804
# Kiteretsu Daihyakka                                  7.583864
# Kabatotto                                            7.686496
# Keroro Gunsou                                        8.333344
# Wushen Zhuzai                                        9.601067
# Naruto: Shippuuden                                  14.845357
# Perman (1983)                                       16.674206
# Xi Yangyang Yu Hui Tailang                          17.069094
# Ninja Hattori-kun                                   24.907227
#
#                                            Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                               4.456667
# InuYasha                                             4.463333
# Fairy Tail                                           5.643333
# Yu☆Gi☆Oh! Duel Monsters                              6.440000
# Tennis no Ouji-sama                                  7.246667
# Black Clover                                         7.086667
# Gintama                                              8.963333
# Urusei Yatsura                                      10.323333
# Ranma ½                                              6.630000
# Pokemon Diamond & Pearl                              8.463333
# Yu☆Gi☆Oh! Duel Monsters GX                           8.486667
# Pokemon Advanced Generation                          9.713333
# Yadamon                                             10.673333
# Wagamama☆Fairy Mirumo de Pon!                       10.333333
# Tetsuwan Atom                                       10.723333
# Pokonyan!                                           12.426667
# Ni Tian Zhizun                                      12.713333
# Pokemon                                             11.260000
# Dragon Ball Z                                        8.430000
# Youkai Watch                                        15.093333
# Chirorin Mura Monogatari                            15.106667
# Furusato Saisei: Nippon no Mukashibanashi           15.653333
# Tottoko Hamtarou                                    13.020000
# Boruto: Naruto Next Generations                      9.730000
# Ikkyuu-san                                          17.773333
# Atashin'chi                                         17.373333
# Kiteretsu Daihyakka                                 18.443333
# Kabatotto                                           19.933333
# Keroro Gunsou                                       18.053333
# Wushen Zhuzai                                       19.073333
# Naruto: Shippuuden                                  15.986667
# Perman (1983)                                       26.693333
# Xi Yangyang Yu Hui Tailang                          29.280000
# Ninja Hattori-kun                                   36.413333
#
#                                            Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!                              0.995178
# InuYasha                                            0.995811
# Fairy Tail                                          0.996150
# Yu☆Gi☆Oh! Duel Monsters                             0.991842
# Tennis no Ouji-sama                                 0.992801
# Black Clover                                        0.990869
# Gintama                                             0.990810
# Urusei Yatsura                                      0.988307
# Ranma ½                                             0.989501
# Pokemon Diamond & Pearl                             0.991118
# Yu☆Gi☆Oh! Duel Monsters GX                          0.992834
# Pokemon Advanced Generation                         0.989005
# Yadamon                                             0.990136
# Wagamama☆Fairy Mirumo de Pon!                       0.985682
# Tetsuwan Atom                                       0.983908
# Pokonyan!                                           0.987990
# Ni Tian Zhizun                                      0.971957
# Pokemon                                             0.973562
# Dragon Ball Z                                       0.981524
# Youkai Watch                                        0.972091
# Chirorin Mura Monogatari                            0.980778
# Furusato Saisei: Nippon no Mukashibanashi           0.963840
# Tottoko Hamtarou                                    0.956340
# Boruto: Naruto Next Generations                     0.949060
# Ikkyuu-san                                          0.946804
# Atashin'chi                                         0.944568
# Kiteretsu Daihyakka                                 0.936945
# Kabatotto                                           0.921068
# Keroro Gunsou                                       0.945145
# Wushen Zhuzai                                       0.927545
# Naruto: Shippuuden                                  0.907969
# Perman (1983)                                       0.844440
# Xi Yangyang Yu Hui Tailang                          0.830221
# Ninja Hattori-kun                                   0.794174
# 34
# k Value:25
#                                        Eucldiean Distance  Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                           1.917895            4.456667
# InuYasha                                         2.247618            4.463333
# Fairy Tail                                       2.417641            5.643333
# Yu☆Gi☆Oh! Duel Monsters                          2.525831            6.440000
# Tennis no Ouji-sama                              2.586366            7.246667
# Black Clover                                     2.729827            7.086667
# Gintama                                          2.995072            8.963333
# Urusei Yatsura                                   3.054339           10.323333
# Ranma ½                                          3.087144            6.630000
# Pokemon Diamond & Pearl                          3.128970            8.463333
# Yu☆Gi☆Oh! Duel Monsters GX                       3.158263            8.486667
# Dragon Ball                                      3.296431            7.963333
# Hunter x Hunter (2011)                           3.305040            5.480000
# Pokemon Advanced Generation                      3.453880            9.713333
# Yu☆Gi☆Oh! 5D's                                   3.458510            8.286667
# Yadamon                                          3.624613           10.673333
# Kindaichi Shounen no Jikenbo                     3.727102            9.920000
# Toriko                                           3.745262            9.143333
# Konjiki no Gash Bell!!                           3.754991            9.953333
# Wagamama☆Fairy Mirumo de Pon!                    3.904129           10.333333
# Tetsuwan Atom                                    3.975297           10.723333
# Pokonyan!                                        4.123084           12.426667
# Dragon Ball Super                                4.322459            9.123333
# Kirarin☆Revolution                               4.364377           13.096667
# Yu☆Gi☆Oh! Arc-V                                  4.372896            9.066667
# Pokemon (2019)                                   4.454117           11.593333
# Pokemon Sun & Moon                               4.631467           11.826667
# Mainichi Kaasan                                  4.691363           13.466667
# Wanmei Shijie                                    4.715106           12.233333
# Yuu☆Yuu☆Hakusho                                  4.881320            8.453333
# Saiki Kusuo no Ψ-nan                             4.924614           11.973333
# Youkai Watch                                     4.969489           15.093333
# Chirorin Mura Monogatari                         5.042733           15.106667
# Saint Seiya                                      5.102505           11.333333
# D.Gray-man                                       5.254235            8.343333
# Fairy Tail (2014)                                5.398354            9.133333
# Dragon Quest: Dai no Daibouken (2020)            5.460216            9.053333
# Spoon Oba-san                                    5.588067           15.906667
# Hokuto no Ken                                    5.637357           13.830000
# Meme Iroiro Yume no Tabi                         5.647990           15.703333
# Manga Sekai Mukashibanashi                       5.650645           15.203333
# Yu☆Gi☆Oh! VRAINS                                 5.684185           13.546667
# Bouken Shounen Shadar                            5.687983           14.773333
# Dragon Ball Kai                                  5.694060           10.223333
# Tunshi Xingkong 2nd Season                       5.711388           13.753333
# Ginga Tetsudou 999                               5.719935           14.323333
# Slam Dunk                                        5.775447           13.163333
# Tiger Mask                                       5.821608           13.996667
# Uchuu Kyoudai                                    5.855031           13.183333
# Kodomo no Omocha (TV)                            5.865034           14.646667
#
#                                        Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!                          0.995178
# InuYasha                                        0.995811
# Fairy Tail                                      0.996150
# Yu☆Gi☆Oh! Duel Monsters                         0.991842
# Tennis no Ouji-sama                             0.992801
# Black Clover                                    0.990869
# Gintama                                         0.990810
# Urusei Yatsura                                  0.988307
# Ranma ½                                         0.989501
# Pokemon Diamond & Pearl                         0.991118
# Yu☆Gi☆Oh! Duel Monsters GX                      0.992834
# Dragon Ball                                     0.987981
# Hunter x Hunter (2011)                          0.985958
# Pokemon Advanced Generation                     0.989005
# Yu☆Gi☆Oh! 5D's                                  0.991856
# Yadamon                                         0.990136
# Kindaichi Shounen no Jikenbo                    0.984097
# Toriko                                          0.988040
# Konjiki no Gash Bell!!                          0.987468
# Wagamama☆Fairy Mirumo de Pon!                   0.985682
# Tetsuwan Atom                                   0.983908
# Pokonyan!                                       0.987990
# Dragon Ball Super                               0.984836
# Kirarin☆Revolution                              0.986069
# Yu☆Gi☆Oh! Arc-V                                 0.994255
# Pokemon (2019)                                  0.981056
# Pokemon Sun & Moon                              0.988619
# Mainichi Kaasan                                 0.983437
# Wanmei Shijie                                   0.980207
# Yuu☆Yuu☆Hakusho                                 0.969372
# Saiki Kusuo no Ψ-nan                            0.968644
# Youkai Watch                                    0.972091
# Chirorin Mura Monogatari                        0.980778
# Saint Seiya                                     0.971209
# D.Gray-man                                      0.967475
# Fairy Tail (2014)                               0.969760
# Dragon Quest: Dai no Daibouken (2020)           0.967682
# Spoon Oba-san                                   0.980474
# Hokuto no Ken                                   0.959713
# Meme Iroiro Yume no Tabi                        0.979511
# Manga Sekai Mukashibanashi                      0.973824
# Yu☆Gi☆Oh! VRAINS                                0.980975
# Bouken Shounen Shadar                           0.986417
# Dragon Ball Kai                                 0.963891
# Tunshi Xingkong 2nd Season                      0.962131
# Ginga Tetsudou 999                              0.962121
# Slam Dunk                                       0.955909
# Tiger Mask                                      0.967700
# Uchuu Kyoudai                                   0.954791
# Kodomo no Omocha (TV)                           0.956937
# 73
# k Value:50
#                                Eucldiean Distance  Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                   1.917895            4.456667
# InuYasha                                 2.247618            4.463333
# Fairy Tail                               2.417641            5.643333
# Yu☆Gi☆Oh! Duel Monsters                  2.525831            6.440000
# Tennis no Ouji-sama                      2.586366            7.246667
# Black Clover                             2.729827            7.086667
# Gintama                                  2.995072            8.963333
# Urusei Yatsura                           3.054339           10.323333
# Ranma ½                                  3.087144            6.630000
# Pokemon Diamond & Pearl                  3.128970            8.463333
# Yu☆Gi☆Oh! Duel Monsters GX               3.158263            8.486667
# Dragon Ball                              3.296431            7.963333
# Hunter x Hunter (2011)                   3.305040            5.480000
# Pokemon Advanced Generation              3.453880            9.713333
# Yu☆Gi☆Oh! 5D's                           3.458510            8.286667
# Yadamon                                  3.624613           10.673333
# Kindaichi Shounen no Jikenbo             3.727102            9.920000
# Toriko                                   3.745262            9.143333
# Konjiki no Gash Bell!!                   3.754991            9.953333
# Wagamama☆Fairy Mirumo de Pon!            3.904129           10.333333
# Tetsuwan Atom                            3.975297           10.723333
# Pokonyan!                                4.123084           12.426667
# Dragon Ball Super                        4.322459            9.123333
# Kirarin☆Revolution                       4.364377           13.096667
# Yu☆Gi☆Oh! Arc-V                          4.372896            9.066667
# Pokemon (2019)                           4.454117           11.593333
# Pokemon Sun & Moon                       4.631467           11.826667
# Mainichi Kaasan                          4.691363           13.466667
# Youkai Watch                             4.969489           15.093333
# Chirorin Mura Monogatari                 5.042733           15.106667
#
#                                Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!                  0.995178
# InuYasha                                0.995811
# Fairy Tail                              0.996150
# Yu☆Gi☆Oh! Duel Monsters                 0.991842
# Tennis no Ouji-sama                     0.992801
# Black Clover                            0.990869
# Gintama                                 0.990810
# Urusei Yatsura                          0.988307
# Ranma ½                                 0.989501
# Pokemon Diamond & Pearl                 0.991118
# Yu☆Gi☆Oh! Duel Monsters GX              0.992834
# Dragon Ball                             0.987981
# Hunter x Hunter (2011)                  0.985958
# Pokemon Advanced Generation             0.989005
# Yu☆Gi☆Oh! 5D's                          0.991856
# Yadamon                                 0.990136
# Kindaichi Shounen no Jikenbo            0.984097
# Toriko                                  0.988040
# Konjiki no Gash Bell!!                  0.987468
# Wagamama☆Fairy Mirumo de Pon!           0.985682
# Tetsuwan Atom                           0.983908
# Pokonyan!                               0.987990
# Dragon Ball Super                       0.984836
# Kirarin☆Revolution                      0.986069
# Yu☆Gi☆Oh! Arc-V                         0.994255
# Pokemon (2019)                          0.981056
# Pokemon Sun & Moon                      0.988619
# Mainichi Kaasan                         0.983437
# Youkai Watch                            0.972091
# Chirorin Mura Monogatari                0.980778
# 30
# k Value:75
#                                Eucldiean Distance  Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                   1.917895            4.456667
# InuYasha                                 2.247618            4.463333
# Fairy Tail                               2.417641            5.643333
# Yu☆Gi☆Oh! Duel Monsters                  2.525831            6.440000
# Tennis no Ouji-sama                      2.586366            7.246667
# Black Clover                             2.729827            7.086667
# Gintama                                  2.995072            8.963333
# Urusei Yatsura                           3.054339           10.323333
# Ranma ½                                  3.087144            6.630000
# Pokemon Diamond & Pearl                  3.128970            8.463333
# Yu☆Gi☆Oh! Duel Monsters GX               3.158263            8.486667
# Dragon Ball                              3.296431            7.963333
# Hunter x Hunter (2011)                   3.305040            5.480000
# Pokemon Advanced Generation              3.453880            9.713333
# Yu☆Gi☆Oh! 5D's                           3.458510            8.286667
# Yadamon                                  3.624613           10.673333
# Kindaichi Shounen no Jikenbo             3.727102            9.920000
# Toriko                                   3.745262            9.143333
# Konjiki no Gash Bell!!                   3.754991            9.953333
# Wagamama☆Fairy Mirumo de Pon!            3.904129           10.333333
# Tetsuwan Atom                            3.975297           10.723333
# Pokonyan!                                4.123084           12.426667
# Dragon Ball Super                        4.322459            9.123333
# Kirarin☆Revolution                       4.364377           13.096667
# Pokemon (2019)                           4.454117           11.593333
# Youkai Watch                             4.969489           15.093333
#
#                                Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!                  0.995178
# InuYasha                                0.995811
# Fairy Tail                              0.996150
# Yu☆Gi☆Oh! Duel Monsters                 0.991842
# Tennis no Ouji-sama                     0.992801
# Black Clover                            0.990869
# Gintama                                 0.990810
# Urusei Yatsura                          0.988307
# Ranma ½                                 0.989501
# Pokemon Diamond & Pearl                 0.991118
# Yu☆Gi☆Oh! Duel Monsters GX              0.992834
# Dragon Ball                             0.987981
# Hunter x Hunter (2011)                  0.985958
# Pokemon Advanced Generation             0.989005
# Yu☆Gi☆Oh! 5D's                          0.991856
# Yadamon                                 0.990136
# Kindaichi Shounen no Jikenbo            0.984097
# Toriko                                  0.988040
# Konjiki no Gash Bell!!                  0.987468
# Wagamama☆Fairy Mirumo de Pon!           0.985682
# Tetsuwan Atom                           0.983908
# Pokonyan!                               0.987990
# Dragon Ball Super                       0.984836
# Kirarin☆Revolution                      0.986069
# Pokemon (2019)                          0.981056
# Youkai Watch                            0.972091
# 26
# k Value:100
#                                Eucldiean Distance  Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                   1.917895            4.456667
# InuYasha                                 2.247618            4.463333
# Fairy Tail                               2.417641            5.643333
# Yu☆Gi☆Oh! Duel Monsters                  2.525831            6.440000
# Tennis no Ouji-sama                      2.586366            7.246667
# Black Clover                             2.729827            7.086667
# Gintama                                  2.995072            8.963333
# Urusei Yatsura                           3.054339           10.323333
# Ranma ½                                  3.087144            6.630000
# Pokemon Diamond & Pearl                  3.128970            8.463333
# Yu☆Gi☆Oh! Duel Monsters GX               3.158263            8.486667
# Dragon Ball                              3.296431            7.963333
# Hunter x Hunter (2011)                   3.305040            5.480000
# Pokemon Advanced Generation              3.453880            9.713333
# Yu☆Gi☆Oh! 5D's                           3.458510            8.286667
# Yadamon                                  3.624613           10.673333
# Kindaichi Shounen no Jikenbo             3.727102            9.920000
# Toriko                                   3.745262            9.143333
# Konjiki no Gash Bell!!                   3.754991            9.953333
# Wagamama☆Fairy Mirumo de Pon!            3.904129           10.333333
# Tetsuwan Atom                            3.975297           10.723333
# Pokonyan!                                4.123084           12.426667
# Kirarin☆Revolution                       4.364377           13.096667
# Youkai Watch                             4.969489           15.093333
#
#                                Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!                  0.995178
# InuYasha                                0.995811
# Fairy Tail                              0.996150
# Yu☆Gi☆Oh! Duel Monsters                 0.991842
# Tennis no Ouji-sama                     0.992801
# Black Clover                            0.990869
# Gintama                                 0.990810
# Urusei Yatsura                          0.988307
# Ranma ½                                 0.989501
# Pokemon Diamond & Pearl                 0.991118
# Yu☆Gi☆Oh! Duel Monsters GX              0.992834
# Dragon Ball                             0.987981
# Hunter x Hunter (2011)                  0.985958
# Pokemon Advanced Generation             0.989005
# Yu☆Gi☆Oh! 5D's                          0.991856
# Yadamon                                 0.990136
# Kindaichi Shounen no Jikenbo            0.984097
# Toriko                                  0.988040
# Konjiki no Gash Bell!!                  0.987468
# Wagamama☆Fairy Mirumo de Pon!           0.985682
# Tetsuwan Atom                           0.983908
# Pokonyan!                               0.987990
# Kirarin☆Revolution                      0.986069
# Youkai Watch                            0.972091
# 24
# k Value:150
#                               Eucldiean Distance  Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                  1.917895            4.456667
# InuYasha                                2.247618            4.463333
# Fairy Tail                              2.417641            5.643333
# Tennis no Ouji-sama                     2.586366            7.246667
# Black Clover                            2.729827            7.086667
# Gintama                                 2.995072            8.963333
# Urusei Yatsura                          3.054339           10.323333
# Ranma ½                                 3.087144            6.630000
# Dragon Ball                             3.296431            7.963333
# Hunter x Hunter (2011)                  3.305040            5.480000
# Yu☆Gi☆Oh! 5D's                          3.458510            8.286667
# Kindaichi Shounen no Jikenbo            3.727102            9.920000
# Toriko                                  3.745262            9.143333
# Konjiki no Gash Bell!!                  3.754991            9.953333
#
#                               Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!                 0.995178
# InuYasha                               0.995811
# Fairy Tail                             0.996150
# Tennis no Ouji-sama                    0.992801
# Black Clover                           0.990869
# Gintama                                0.990810
# Urusei Yatsura                         0.988307
# Ranma ½                                0.989501
# Dragon Ball                            0.987981
# Hunter x Hunter (2011)                 0.985958
# Yu☆Gi☆Oh! 5D's                         0.991856
# Kindaichi Shounen no Jikenbo           0.984097
# Toriko                                 0.988040
# Konjiki no Gash Bell!!                 0.987468
# 14
# k Value:200
#                                Eucldiean Distance  Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!                   1.917895            4.456667
# InuYasha                                 2.247618            4.463333
# Fairy Tail                               2.417641            5.643333
# Yu☆Gi☆Oh! Duel Monsters                  2.525831            6.440000
# Tennis no Ouji-sama                      2.586366            7.246667
# Black Clover                             2.729827            7.086667
# Gintama                                  2.995072            8.963333
# Urusei Yatsura                           3.054339           10.323333
# Ranma ½                                  3.087144            6.630000
# Pokemon Diamond & Pearl                  3.128970            8.463333
# Yu☆Gi☆Oh! Duel Monsters GX               3.158263            8.486667
# Dragon Ball                              3.296431            7.963333
# Pokemon Advanced Generation              3.453880            9.713333
# Yu☆Gi☆Oh! 5D's                           3.458510            8.286667
# Yadamon                                  3.624613           10.673333
# Kindaichi Shounen no Jikenbo             3.727102            9.920000
# Toriko                                   3.745262            9.143333
# Konjiki no Gash Bell!!                   3.754991            9.953333
# Wagamama☆Fairy Mirumo de Pon!            3.904129           10.333333
# Pokonyan!                                4.123084           12.426667
# Kirarin☆Revolution                       4.364377           13.096667
#
#                                Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!                  0.995178
# InuYasha                                0.995811
# Fairy Tail                              0.996150
# Yu☆Gi☆Oh! Duel Monsters                 0.991842
# Tennis no Ouji-sama                     0.992801
# Black Clover                            0.990869
# Gintama                                 0.990810
# Urusei Yatsura                          0.988307
# Ranma ½                                 0.989501
# Pokemon Diamond & Pearl                 0.991118
# Yu☆Gi☆Oh! Duel Monsters GX              0.992834
# Dragon Ball                             0.987981
# Pokemon Advanced Generation             0.989005
# Yu☆Gi☆Oh! 5D's                          0.991856
# Yadamon                                 0.990136
# Kindaichi Shounen no Jikenbo            0.984097
# Toriko                                  0.988040
# Konjiki no Gash Bell!!                  0.987468
# Wagamama☆Fairy Mirumo de Pon!           0.985682
# Pokonyan!                               0.987990
# Kirarin☆Revolution                      0.986069
# 21
# k Value:400
#                         Eucldiean Distance  Manhattan Distance  \
# Recomended Animes
# Katekyo Hitman Reborn!            1.917895            4.456667
# Gintama                           2.995072            8.963333
# Urusei Yatsura                    3.054339           10.323333
#
#                         Cosine Similarity
# Recomended Animes
# Katekyo Hitman Reborn!           0.995178
# Gintama                          0.990810
# Urusei Yatsura                   0.988307
# 3

# %% [markdown]
# ## Dimension Reduction

# %% [markdown]
# ### PCA
# The goal is to reduce the high dimension data to 2D to see how it graphs. This allows for the data to be visualized on a 2D plane.

# %%
# Need to reduce the data from over 100 columns to 2 columns
pca_dim_red = PCA(n_components = 2)
anime_data_2d = pca_dim_red.fit_transform(anime_df)

x_data = list()
y_data = list()
# Grab the x and the y data
for i in range (0, len(anime_data_2d)):
    x_data.append(anime_data_2d[i][0])
    y_data.append(anime_data_2d[i][1])
    
# Graph the data that was derived
plt.figure(figsize = (20, 25))
plt.scatter(x_data, y_data, s = 4)
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('PCA on Anime Data')
plt.show()
